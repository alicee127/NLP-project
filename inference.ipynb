# %%
import os
import pandas as pd
import transformers

from src.dataset import BLEnDDataset
from src.prompts import PromptBuilder
from src.LLMWrapper import LLMWrapper

# %%
countries = ['China', 'Spain', 'Greece', 'Indonesia', 'Algeria']
annotations_dir = 'data/annotations'

dataset = BLEnDDataset(countries)
dataset.load(annotations_dir)
# Out:
# {'China':     question_id           local_question  \
#  0      Al-en-01       在中国，学龄前儿童常见的零食是什么？
#  1      Al-en-02    在中国，有什么受欢迎的食物可以搭配啤酒吃？
#  2      Al-en-04           在中国最受欢迎的水果是什么？
#  3      Al-en-06       在中国的学校食堂里常见的食物是什么？
#  4      Al-en-08     在中国的购物中心里，最常见的零食有哪些？
#  ..          ...                      ...
#  495    Th-en-53  在中国的学校里，最受欢迎的课外社交活动是什么？
#  496    Th-en-58   在中国大学之前，学的最高级的数学科目是什么？
#  497   Tmp-ar-01     中国的大学生通常去哪里复习准备期末考试？
#  498   Tmp-ar-02   在中国，人们通常乘坐什么公共交通工具去大学？
#  499   Tmp-ar-04         中国的小学生放学后通常做些什么？
#
#                                             en_question  \
#  0    What is a common snack for preschool kids in C...
#  1     What is a popular food to go with beer in China?
#  2             What is the most popular fruit in China?
#  3     What is a common school cafeteria food in China?
#  4    What are the most commonly eaten snacks at sho...
#  ..                                                 ...
#  495  What is the most popular extracurricular socia...
#  496  What is the most advanced math subject learned...
#  497  Where do university students in China usually ...
#  498  What is a common public transport that people ...
#  499  What do elementary students in China usually d...
#
#                                      local_answer_valid  \
#  0    [奶酪棒, 芝士棒, 水果干, 薯片, 糖果, 糖, 冰棍, 雪糕, 冰激凌, ad钙奶, ...
#  1           [花生米, 花生, 炸鸡, 虾干, 干虾, 开心果, 烧鸡, 烤鸡, 烧烤, 烤串]
#  2                                  [橘子, 苹果, 西瓜, 梨子, 梨]
#  3    [面食, 面条, 包子, 炒菜, 白饭, 米饭, 大米饭, 麻辣香锅, 番茄炒鸡蛋, 番茄炒...
#  4                     [薯片, 旺旺, 糖果, 糖, 糕点, 瓜子, 辣子条, 辣条]
#  ..                                                 ...
#  495                   [去网吧, 卡拉ok, 玩游戏, 社团, 学术竞赛, 王者荣耀]
#  496                    [微积分, 解析几何, 线性代数, 高中数学, 代数, 几何]
#  497                                         [图书馆, 自习室]
#  498                             [地铁, 滴滴快车, 火车, 汽车, 飞机]
#  499                  [做作业, 写作业, 玩弹珠游戏, 去游乐场, 吃饭, 看中央1]
#
#                                         en_answer_valid country
#  0    [cheese stick, dried fruit, potato chips, chip...   China
#  1    [peanuts, fried chicken, dried shrimp, pistach...   China
#  2                    [orange, apple, watermelon, pear]   China
#  3    [noodles, cooked wheaten food, pasta, steamed ...   China
#  4    [potato chips, chips, wangwang, sweet, sweets,...   China
#  ..                                                 ...     ...
#  495  [go to the internet cafe, karaoke, play games,...   China
#  496  [calculus, analytic geometry, linear algebra, ...   China
#  497                              [library, study room]   China
#  498  [metro, subway, didi express, train, car, airp...   China
#  499  [do homework, play marbles game, go to the amu...   China
#
#  [500 rows x 6 columns],
#  'Spain':     question_id                                     local_question  \
#  0      Al-en-01  ¿Cuál es un tentempié común para niños de pree...
#  1      Al-en-02  ¿Cuál es una comida popular para acompañar la ...
#  2      Al-en-04           ¿Cuál es la fruta más popular en España?
#  3      Al-en-06  ¿Cuál es una comida común en las cafeterías es...
#  4      Al-en-08  ¿Cuáles son los aperitivos más consumidos en l...
#  ..          ...                                                ...
#  495    Th-en-53  ¿Cuál es el evento social extracurricular más ...
#  496    Th-en-58  ¿Cuál es la tema de matemáticas más avanzado q...
#  497   Tmp-ar-01  ¿Dónde suelen ir los estudiantes universitario...
#  498   Tmp-ar-02  ¿Cuál es un transporte público común que la ge...
#  499   Tmp-ar-04  ¿Qué suelen hacer los estudiantes de primaria ...
#
#                                             en_question  \
#  0    What is a common snack for preschool kids in S...
#  1     What is a popular food to go with beer in Spain?
#  2             What is the most popular fruit in Spain?
#  3     What is a common school cafeteria food in Spain?
#  4    What are the most commonly eaten snacks at sho...
#  ..                                                 ...
#  495  What is the most popular extracurricular socia...
#  496  What is the most advanced math subject learned...
#  497  Where do university students in Spain usually ...
#  498  What is a common public transport that people ...
#  499  What do elementary students in Spain usually d...
#
#                                      local_answer_valid  \
#  0    [fruta, pieza de fruta, sandwich, bocadillo, g...
#  1    [tapas, patatas bravas, papas bravas, patatas ...
#  2    [naranja, melon, platano, plátano, sandia, man...
#  3    [tortilla de patatas, tortilla, croquetas, pol...
#  4    [patatas fritas, helado, helados, yogurt helad...
#  ..                                                 ...
#  495  [fútbol, baile, graduación, fin de año escolar...
#  496  [álgebra, integrales, fracciones, raíz cuadrad...
#  497  [biblioteca universidad, bibliotecas, bibliote...
#  498                    [autobús, bus, metro, el metro]
#  499  [asignaturas extraescolares, actividades extra...
#
#                                         en_answer_valid country
#  0    [fruit, piece of fruit, sandwich, cookies, bis...   Spain
#  1    [tapas, spicy potatoes, bag of crisps, peanuts...   Spain
#  2           [orange, melon, banana, watermelon, apple]   Spain
#  3    [spanish omelette, croquettes, chicken, macaro...   Spain
#  4    [french fried, fries, ice cream, ice creams, f...   Spain
#  ..                                                 ...     ...
#  495  [soccer, football, dance, graduation, end of t...   Spain
#  496  [algebra, integrals, fractions, square root, s...   Spain
#  497  [university library, libraries, library, home,...   Spain
#  498                   [bus, metro, subway, the subway]   Spain
#  499  [extracurricular subjects, extracurricular act...   Spain
#
#  [500 rows x 6 columns],
#  'Greece':     question_id                                     local_question  \
#  0      Al-en-01  Ποιο είναι ένα συνηθισμένο σνακ για παιδιά προ...
#  1      Al-en-02  Ποιο είναι ένα δημοφιλές φαγητό που συνοδεύει ...
#  2      Al-en-04    Ποιο είναι το πιο δημοφιλές φρούτο στην Ελλάδα;
#  3      Al-en-06  Ποιο είναι ένα συνηθισμένο φαγητό στα σχολεία ...
#  4      Al-en-08  Ποια είναι τα πιο συνηθισμένα σνακ που καταναλ...
#  ..          ...                                                ...
#  495    Th-en-53  Ποια είναι η πιο δημοφιλής εξωσχολική κοινωνικ...
#  496    Th-en-58  Ποιο είναι το πιο προχωρημένο μάθημα μαθηματικ...
#  497   Tmp-ar-01  Πού συνήθως πηγαίνουν οι φοιτητές στην Ελλάδα ...
#  498   Tmp-ar-02  Ποιο είναι ένα κοινό μέσο δημόσιας μεταφοράς π...
#  499   Tmp-ar-04  Τι συνήθως κάνουν οι μαθητές του δημοτικού στη...
#
#                                             en_question  \
#  0    What is a common snack for preschool kids in G...
#  1    What is a popular food to go with beer in Greece?
#  2            What is the most popular fruit in Greece?
#  3    What is a common school cafeteria food in Greece?
#  4    What are the most commonly eaten snacks at sho...
#  ..                                                 ...
#  495  What is the most popular extracurricular socia...
#  496  What is the most advanced math subject learned...
#  497  Where do university students in Greece usually...
#  498  What is a common public transport that people ...
#  499  What do elementary students in Greece usually ...
#
#                                      local_answer_valid  \
#  0    [τοστ, κουλούρι, Greek sesame bread rings, φρο...
#  1                     [σουβλάκι, λουκάνικο, πατατάκια]
#  2    [καρπούζι, μήλο, πεπόνι, μανταρίνι, πορτοκάλι,...
#  3    [σάντουιτς, τυρόπιτα, κρουασάν, κουλούρι, τοστ...
#  4    [σουβλάκι, πίτσα, κρουασάν, ποπκόρν, πατατάκια...
#  ..                                                 ...
#  495  [ξενάγηση στον Παρθενώνα, πανηγύρι, σινεμά, θέ...
#  496                                     [ολοκληρώματα]
#  497  [βιβλιοθήκη, σπίτι, φροντιστήριο, βιβλιοθήκες ...
#  498       [αστικό, αστικό λεωφορείο, λεωφορείο, μετρό]
#  499  [γυρίζουν σπίτι για φαγητό, τρώνε, παίζουν, σπ...
#
#                                         en_answer_valid country
#  0        [toast, koulouri, fruit, biscuits, chocolate]  Greece
#  1                    [souvlaki, sausage, potato chips]  Greece
#  2    [watermelon, apple, melon, mandarin, orange, b...  Greece
#  3    [sandwich, cheese pie, croissant, greek sesame...  Greece
#  4    [souvlaki, pizza, croissant, popcorn, potato c...  Greece
#  ..                                                 ...     ...
#  495  [tour of the parthenon, festival, cinema, thea...  Greece
#  496                                        [integrals]  Greece
#  497  [library, house, tutorial center, school libra...  Greece
#  498                             [city bus, bus, metro]  Greece
#  499  [return home for food, eat, play, house, go fo...  Greece
#
#  [500 rows x 6 columns],
#  'Indonesia':     question_id                                     local_question  \
#  0      Al-en-01  Apa camilan umum untuk anak-anak TK di Indonesia?
#  1      Al-en-02  Apa makanan populer yang cocok disantap bersam...
#  2      Al-en-04         Buah apa yang paling populer di Indonesia?
#  3      Al-en-06  Apa makanan kantin sekolah yang umum di Indone...
#  4      Al-en-08  Apa saja camilan yang paling sering dimakan di...
#  ..          ...                                                ...
#  495    Th-en-53  Apa kegiatan ekstrakurikuler sosial yang palin...
#  496    Th-en-58  Apa mata pelajaran matematika tingkat lanjut t...
#  497   Tmp-ar-01  Di mana mahasiswa di Indonesia biasanya belaja...
#  498   Tmp-ar-02  Apa transportasi umum yang sering digunakan or...
#  499   Tmp-ar-04  Apa yang biasanya dilakukan oleh siswa sekolah...
#
#                                             en_question  \
#  0    What is a common snack for preschool kids in I...
#  1    What is a popular food to go with beer in Indo...
#  2         What is the most popular fruit in Indonesia?
#  3    What is a common school cafeteria food in Indo...
#  4    What are the most commonly eaten snacks at sho...
#  ..                                                 ...
#  495  What is the most popular extracurricular socia...
#  496  What is the most advanced math subject learned...
#  497  Where do university students in Indonesia usua...
#  498  What is a common public transport that people ...
#  499  What do elementary students in Indonesia usual...
#
#                                      local_answer_valid  \
#  0    [choki-choki, coklat, keripik, telur gulung, w...
#  1    [kacang, ikan bakar, sate ayam, nasi goreng, a...
#  2    [durian, mangga, rambutan, kelapa, pisang, len...
#  3    [nasi goreng, mie goreng, mi goreng, roti baka...
#  4    [gorengan, kacang goreng, kentang goreng, roti...
#  ..                                                 ...
#  495  [basket, seni, sepak bola, paskibra, pasukan p...
#  496  [kalkulus, turunan, integral dan turunan, alge...
#  497  [di perpustakaan, di perpus, perpus, perpustak...
#  498  [sepeda motor, ojek, motor, bis, bus, taksi, k...
#  499  [bimbingan belajar, les tambahan, jajan, main ...
#
#                                         en_answer_valid    country
#  0    [chocolate paste, choki-choki, chocolate, chip...  Indonesia
#  1    [peanut, grilled fish, satay, chicken satay, f...  Indonesia
#  2    [durian, mango, rambutan, coconut, banana, lon...  Indonesia
#  3        [fried rice, fried noodle, toast, mixed rice]  Indonesia
#  4    [fritters, fried peanut, french fries, chips, ...  Indonesia
#  ..                                                 ...        ...
#  495  [basketball, art, soccer, football, troop, bad...  Indonesia
#  496  [calculus, derivative, integral and derivative...  Indonesia
#  497                           [library, at home, cafe]  Indonesia
#  498  [motorcycle, motorbike, ojek, motorcycle taxi,...  Indonesia
#  499  [tutoring, tutoring lesson, buy snacks, play w...  Indonesia
#
#  [500 rows x 6 columns],
#  'Algeria':     question_id                                     local_question  \
#  0      Al-en-01  ماذا يأكل الأطفال كوجبة خفيفة قبل المدرسة في ا...
#  1      Al-en-02  ما هو الطعام الشعبي الذي يتناول مع البيرة في ا...
#  2      Al-en-04             ما هي الفاكهة الأكثر شعبية في الجزائر؟
#  3      Al-en-06     ما هو طعام كافتيريا المدرسة الشائع في الجزائر؟
#  4      Al-en-08  ما هي الوجبات الخفيفة التي يتناولها الناس في م...
#  ..          ...                                                ...
#  495    Th-en-53      ما هو أشهر نشاط اجتماعي في المدارس الجزائرية؟
#  496    Th-en-58  ما هو أصعب موضوع في مادة الرياضيات يُدرس قبل ا...
#  497   Tmp-ar-01  أين يذهب طلاب الجامعة عادة للمذاكرة لامتحاناته...
#  498   Tmp-ar-02  ما هي وسيلة النقل العام الشائعة بين الناس للذه...
#  499   Tmp-ar-04  ما الذي يفعله تلاميذ الإبتدائي في الجزائر عادة...
#
#                                             en_question  \
#  0    What is a common snack for preschool kids in A...
#  1    What is a popular food to go with beer in Alge...
#  2           What is the most popular fruit in Algeria?
#  3    What is a common school cafeteria food in Alge...
#  4    What are the most commonly eaten snacks at sho...
#  ..                                                 ...
#  495  What is the most popular extracurricular socia...
#  496  What is the most advanced math subject learned...
#  497  Where do university students in Algeria usuall...
#  498  What is a common public transport that people ...
#  499  What do elementary students in Algeria usually...
#
#                                      local_answer_valid  \
#  0    [شطائر الخبز بالمربى, خبز بالمربى والزبدة, هلا...
#  1                                                   []
#  2                     [البرتقال, التمر, الموز, البطيخ]
#  3                                              [العدس]
#  4    [بيتزا, البيتزا, همبرقر, برغر, شوارمة, الآيس ك...
#  ..                                                 ...
#  495                          [الحديث, حفلات آخر السنة]
#  496  [التكامل و الاشتقاق, التفاضل و التكامل, المعاد...
#  497  [المكتبة, المكتبة الجامعية, إلى المكتبة, المخا...
#  498  [الباص, الحافلة, القطار, حافلات النقل الجامعي,...
#  499  [يلعبون, يراجعون, الاستراحة, يؤدون الواجبات ال...
#
#                                         en_answer_valid  country
#  0    [jam sandwiches, jam and butter sandwiches, cr...  Algeria
#  1                                                   []  Algeria
#  2                 [orange, dates, bananas, watermelon]  Algeria
#  3                                    [lentils, lentil]  Algeria
#  4    [pizza, hamburger, burger, shawarma, ice cream...  Algeria
#  ..                                                 ...      ...
#  495  [chat, chatting, end of the year parties, end-...  Algeria
#  496  [integration and differentiation, calculus, di...  Algeria
#  497  [library, university library, to the library, ...  Algeria
#  498  [bus, train, transportation service, universit...  Algeria
#  499  [play, they play, they play with their friends...  Algeria
#
#  [500 rows x 6 columns]}

# %%
transformers.logging.set_verbosity_error()
builder = PromptBuilder()

model_name = 'CohereLabs/tiny-aya-global'
llm = LLMWrapper(model_name)
llm.load()

os.makedirs('data/processed', exist_ok=True)
os.makedirs('data/outputs', exist_ok = True)

for country in countries:
    df = dataset.get_country_data(country)

    df['control_prompts'] = builder.build_control_prompts(df)
    df['persona_prompts'] = builder.build_persona_prompts(df)
    df['language_prompts'] = builder.build_language_prompts(df)
    print(f'{country} prompts created')


    df.to_csv(f'data/processed/{country}_prompts.csv', index = False)

    output_df = df.copy()

    output_df['control_output'] = llm.generate_batch(df['control_prompts'])
    output_df['persona_output'] = llm.generate_batch(df['persona_prompts'])
    output_df['language_output'] = llm.generate_batch(df['language_prompts'])
    print(f'{country} outputs generated')


    output_df.to_csv(f'data/outputs/{country}_outputs.csv', index = False)
# Out:
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# China prompts created
# China outputs generated
# Spain prompts created
# Spain outputs generated
# Greece prompts created
# Greece outputs generated
# Indonesia prompts created
# Indonesia outputs generated
# Algeria prompts created
# Algeria outputs generated
